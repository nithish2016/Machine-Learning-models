# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/real_estate_price_size.csv')

# %%
df.head()
# Out:
#         price     size
# 0  234314.144   643.09
# 1  228581.528   656.22
# 2  281626.336   487.29
# 3  401255.608  1504.75
# 4  458674.256  1275.46

# %%
df.isnull().sum()
# Out:
# price    0
# size     0
# dtype: int64

# %%
sns.scatterplot(x = 'size', y = 'price',data = df)
# Out:
# <Axes: xlabel='size', ylabel='price'>

# %%
x = df[['size']]
y = df[['price']]
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# [108225.60858605]
# [[218.60466935]]

# %%
model.predict([[1379],[1234]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[409681.44762414],
#        [377983.77056792]])

# %%
ypred = model.predict(xtest)

plt.scatter(xtrain,ytrain,color='b')
plt.plot(xtest,ypred,color='r')

# %%
ypred = model.predict(xtest)

from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score
print("MAE: ",mean_absolute_error(ypred,ytest))
print("MSE: ",mean_squared_error(ypred,ytest))
print("RMSE: ",root_mean_squared_error(ypred,ytest))
print("r2_score: ",r2_score(ypred,ytest))
# Out:
# MAE:  36124.85490386036
# MSE:  1817037751.3555398
# RMSE:  42626.72578741581
# r2_score:  0.30911615364191114
